# %% [markdown]
# <a href="https://colab.research.google.com/github/ramdarsh/Excelr_assignments/blob/main/Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DELIVERY TIME

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/delivery_time (1).csv")

# %%
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
x = df['Sorting Time']
y = df['Delivery Time']

# %%
b, m = polyfit(x, y, 1)
plt.scatter(x, y)
plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.title('Scatter plot Delivery Time')
plt.xlabel('Sorting Time')
plt.ylabel('Delivery Time')
plt.show()

# %%
corr = np.corrcoef(x, y)
corr
# Out:
# array([[1.        , 0.82599726],
#        [0.82599726, 1.        ]])

# %% [markdown]
# Model

# %%
model = sm.OLS(y, x).fit()
predictions = model.predict(x)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              424.5
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    6.12e-15
# Time:                        10:14:00   Log-Likelihood:                         -57.349
# No. Observations:                  21   AIC:                                      116.7
# Df Residuals:                      20   BIC:                                      117.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
x_log = np.log(df['Sorting Time'])

# %%
model = sm.OLS(y, x_log).fit()
predictions = model.predict(x_log)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.974
# Method:                 Least Squares   F-statistic:                              791.0
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    1.48e-17
# Time:                        10:14:00   Log-Likelihood:                         -51.035
# No. Observations:                  21   AIC:                                      104.1
# Df Residuals:                      20   BIC:                                      105.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_log = np.log(df['Delivery Time'])

# %%
model = sm.OLS(y_log, x).fit()
predictions = model.predict(x)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.917
# Model:                            OLS   Adj. R-squared (uncentered):              0.912
# Method:                 Least Squares   F-statistic:                              219.7
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    3.00e-12
# Time:                        10:14:00   Log-Likelihood:                         -25.284
# No. Observations:                  21   AIC:                                      52.57
# Df Residuals:                      20   BIC:                                      53.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_log, x_log).fit()
predictions = model.predict(x_log)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.972
# Model:                            OLS   Adj. R-squared (uncentered):              0.970
# Method:                 Least Squares   F-statistic:                              688.7
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    5.72e-17
# Time:                        10:14:00   Log-Likelihood:                         -13.899
# No. Observations:                  21   AIC:                                      29.80
# Df Residuals:                      20   BIC:                                      30.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
x_sqrt = np.sqrt(df['Sorting Time'])

# %%
model = sm.OLS(y, x_sqrt).fit()
predictions = model.predict(x_sqrt)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              772.0
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    1.88e-17
# Time:                        10:14:00   Log-Likelihood:                         -51.284
# No. Observations:                  21   AIC:                                      104.6
# Df Residuals:                      20   BIC:                                      105.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_sqrt = np.sqrt(df['Delivery Time'])

# %%
model = sm.OLS(y_sqrt, x).fit()
predictions = model.predict(x)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.930
# Model:                            OLS   Adj. R-squared (uncentered):              0.927
# Method:                 Least Squares   F-statistic:                              266.0
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    5.09e-13
# Time:                        10:14:00   Log-Likelihood:                         -31.484
# No. Observations:                  21   AIC:                                      64.97
# Df Residuals:                      20   BIC:                                      66.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_sqrt, x_sqrt).fit()
predictions = model.predict(x_sqrt)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              1542.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):                    2.10e-20
# Time:                        10:14:00   Log-Likelihood:                         -13.658
# No. Observations:                  21   AIC:                                      29.32
# Df Residuals:                      20   BIC:                                      30.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# We will use Model 7 as it has the best R square value.
#
# Adj. R-sqared == 0.987
#
# Thus the model explains 98.7% of the variance in dependent variable

# %% [markdown]
# **SALARY HIKE**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression

# %%
df1=pd.read_csv("/content/Salary_Data (1).csv")

# %%
df1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df1.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sns.displot(df1['Salary'])

# %%
sns.displot(df1['YearsExperience'])

# %%
df1=df1.rename(columns={"YearsExperience":"experience","Salary":"salary"})

# %%
df1
# Out:
#     experience    salary
# 0          1.1   39343.0
# 1          1.3   46205.0
# 2          1.5   37731.0
# 3          2.0   43525.0
# 4          2.2   39891.0
# 5          2.9   56642.0
# 6          3.0   60150.0
# 7          3.2   54445.0
# 8          3.2   64445.0
# 9          3.7   57189.0
# 10         3.9   63218.0
# 11         4.0   55794.0
# 12         4.0   56957.0
# 13         4.1   57081.0
# 14         4.5   61111.0
# 15         4.9   67938.0
# 16         5.1   66029.0
# 17         5.3   83088.0
# 18         5.9   81363.0
# 19         6.0   93940.0
# 20         6.8   91738.0
# 21         7.1   98273.0
# 22         7.9  101302.0
# 23         8.2  113812.0
# 24         8.7  109431.0
# 25         9.0  105582.0
# 26         9.5  116969.0
# 27         9.6  112635.0
# 28        10.3  122391.0
# 29        10.5  121872.0

# %%
model1 = smf.ols("salary~experience",data=df1).fit()

# %%
sns.regplot(x = 'experience' , y = 'salary' , data = df1)
# Out:
# <Axes: xlabel='experience', ylabel='salary'>

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           1.14e-20
# Time:                        10:14:02   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# ...

# %%
xlog=np.log(df1["experience"])

# %%
model2= smf.ols("salary~xlog",data=df1).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     163.6
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           3.25e-13
# Time:                        10:14:02   Log-Likelihood:                -319.77
# No. Observations:                  30   AIC:                             643.5
# Df Residuals:                      28   BIC:                             646.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.493e+04   5156.226      2.895      0.007    4365.921    2.55e+04
# ...

# %%
ylog = np.log(df1["salary"])

# %%
model3=smf.ols("ylog~experience",data=df1).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   ylog   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     383.6
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           7.03e-18
# Time:                        10:14:02   Log-Likelihood:                 28.183
# No. Observations:                  30   AIC:                            -52.37
# Df Residuals:                      28   BIC:                            -49.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.5074      0.038    273.327      0.000      10.429      10.586
# ...

# %%
model4=smf.ols("ylog~xlog",data=df1).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   ylog   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     267.4
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           7.40e-16
# Time:                        10:14:02   Log-Likelihood:                 23.209
# No. Observations:                  30   AIC:                            -42.42
# Df Residuals:                      28   BIC:                            -39.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.3280      0.056    184.868      0.000      10.214      10.442
# ...

# %%
xsqrt=np.sqrt(df1["experience"])

# %%
model5=smf.ols("salary~xsqrt",data=df1).fit()

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     377.8
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           8.57e-18
# Time:                        10:14:02   Log-Likelihood:                -308.52
# No. Observations:                  30   AIC:                             621.0
# Df Residuals:                      28   BIC:                             623.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.606e+04   4921.599     -3.262      0.003   -2.61e+04   -5974.331
# ...

# %%
ysqrt=np.sqrt(df1["salary"])

# %%
model6=smf.ols("ysqrt~experience",data=df1).fit()

# %%
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  ysqrt   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     530.2
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           9.78e-20
# Time:                        10:14:02   Log-Likelihood:                -114.33
# No. Observations:                  30   AIC:                             232.7
# Df Residuals:                      28   BIC:                             235.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    180.7002      4.446     40.646      0.000     171.594     189.807
# ...

# %%
model7=smf.ols("ysqrt~xsqrt",data=df1).fit()

# %%
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  ysqrt   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     454.3
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           7.58e-19
# Time:                        10:14:02   Log-Likelihood:                -116.52
# No. Observations:                  30   AIC:                             237.0
# Df Residuals:                      28   BIC:                             239.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    103.5680      8.178     12.663      0.000      86.815     120.321
# ...

# %%
model1.fittedvalues
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
df1["predicted"]=model1.fittedvalues

# %%
df1["error"]=df1["salary"]-df1["predicted"]

# %%
df1
# Out:
#     experience    salary      predicted         error
# 0          1.1   39343.0   36187.158752   3155.841248
# 1          1.3   46205.0   38077.151217   8127.848783
# 2          1.5   37731.0   39967.143681  -2236.143681
# 3          2.0   43525.0   44692.124842  -1167.124842
# 4          2.2   39891.0   46582.117306  -6691.117306
# 5          2.9   56642.0   53197.090931   3444.909069
# 6          3.0   60150.0   54142.087163   6007.912837
# 7          3.2   54445.0   56032.079627  -1587.079627
# 8          3.2   64445.0   56032.079627   8412.920373
# 9          3.7   57189.0   60757.060788  -3568.060788
# 10         3.9   63218.0   62647.053252    570.946748
# 11         4.0   55794.0   63592.049484  -7798.049484
# 12         4.0   56957.0   63592.049484  -6635.049484
# 13         4.1   57081.0   64537.045717  -7456.045717
# 14         4.5   61111.0   68317.030645  -7206.030645
# 15         4.9   67938.0   72097.015574  -4159.015574
# ...

# %% [markdown]
# We will use Model 1 as it has the best R square value.
#
# Adj. R-sqared == 0.957
#
# Thus the model explains 95.7% of the variance in dependent variable
